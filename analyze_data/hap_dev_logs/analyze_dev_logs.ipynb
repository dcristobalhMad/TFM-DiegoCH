# %%
import pandas as pd

df = pd.read_csv ('haproxy.log', delim_whitespace=True, header=None)
df.to_csv ('haproxy.csv', sep=' ', index=False)

# %%
df
# Out:
#                  0               1                           2     3   \
# 0    10.4.5.1:47404  10.4.5.21:8100  [26/Apr/2023:19:51:39.007]  http
# 1    10.4.5.1:47406  10.4.5.21:8100  [26/Apr/2023:19:51:42.010]  http
# 2    10.4.5.1:51164  10.4.5.21:8100  [26/Apr/2023:19:51:45.009]  http
# 3    10.4.5.1:51190  10.4.5.21:8100  [26/Apr/2023:19:51:48.010]  http
# 4    10.4.5.1:51196  10.4.5.21:8100  [26/Apr/2023:19:51:51.009]  http
# ..              ...             ...                         ...   ...
# 310  10.4.5.1:49884  10.4.5.21:8100  [26/Apr/2023:20:04:33.010]  http
# 311  10.4.5.1:45930  10.4.5.21:8100  [26/Apr/2023:20:04:36.010]  http
# 312  10.4.5.1:49854  10.4.5.21:8100  [26/Apr/2023:20:04:26.180]  http
# 313  10.4.5.1:45942  10.4.5.21:8100  [26/Apr/2023:20:04:39.006]  http
# 314  10.4.5.1:45954  10.4.5.21:8100  [26/Apr/2023:20:04:42.009]  http
#
#                4                5    6    7  8  9     10         11   12  \
# ...
